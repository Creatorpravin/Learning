# %%
import pandas as pd

# %%
df = pd.read_csv('tips.csv')

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df = pd.read_excel("Tracker.xlsx", sheet_name="Pine script")

# %%
df
# Out:
#     S No                         Chapter  \
# 0      1                 1. Introduction
# 1      2                 1. Introduction
# 2      3                 1. Introduction
# 3      4                 1. Introduction
# 4      5           2. Pine Script Editor
# 5      6           2. Pine Script Editor
# 6      7           2. Pine Script Editor
# 7      8              3. Building Blocks
# 8      9              3. Building Blocks
# 9     10              3. Building Blocks
# 10    11              3. Building Blocks
# 11    12              3. Building Blocks
# 12    13              3. Building Blocks
# 13    14              3. Building Blocks
# 14    15              3. Building Blocks
# 15    16              3. Building Blocks
# 16    17        4. Expanding Your Skills
# 17    18        4. Expanding Your Skills
# 18    19        4. Expanding Your Skills
# 19    20        4. Expanding Your Skills
# 20    21        4. Expanding Your Skills
# 21    22        4. Expanding Your Skills
# ...
