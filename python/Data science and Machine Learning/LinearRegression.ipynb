# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data_set = pd.read_csv("Salary_Data.csv")

# %%
data_set.head()
# Out:
#    YearsExperience   Salary
# 0              1.1  39343.0
# 1              1.3  46205.0
# 2              1.5  37731.0
# 3              2.0  43525.0
# 4              2.2  39891.0

# %%
x = data_set.iloc[:,:-1].values #get the last before row
y = data_set.iloc[:,1].values #get the last row

# %%
x
# Out:
# array([[ 1.1],
#        [ 1.3],
#        [ 1.5],
#        [ 2. ],
#        [ 2.2],
#        [ 2.9],
#        [ 3. ],
#        [ 3.2],
#        [ 3.2],
#        [ 3.7],
#        [ 3.9],
#        [ 4. ],
#        [ 4. ],
#        [ 4.1],
#        [ 4.5],
#        [ 4.9],
#        [ 5.1],
#        [ 5.3],
#        [ 5.9],
#        [ 6. ],
#        [ 6.8],
#        [ 7.1],
#        [ 7.9],
#        [ 8.2],
#        [ 8.7],
#        [ 9. ],
#        [ 9.5],
#        [ 9.6],
#        [10.3],
#        [10.5]])

# %%
y
# Out:
# array([ 39343.,  46205.,  37731.,  43525.,  39891.,  56642.,  60150.,
#         54445.,  64445.,  57189.,  63218.,  55794.,  56957.,  57081.,
#         61111.,  67938.,  66029.,  83088.,  81363.,  93940.,  91738.,
#         98273., 101302., 113812., 109431., 105582., 116969., 112635.,
#        122391., 121872.])

# %% [markdown]
# # Split the data for test and train

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.2) # Use 20 % for test

# %%
from sklearn.linear_model import LinearRegression

# %%
reg = LinearRegression()

# %%
reg.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = reg.predict(x_test)
x_pred = reg.predict(x_train)

# %%
y_pred
# Out:
# array([ 64917.66736783, 100261.44814937,  56546.77191957, 103051.74663213,
#         72358.46332184, 116073.13955164])

# %%
x_pred
# Out:
# array([107702.24410338,  38874.8815288 , 115143.04005739,  68638.06534484,
#         82589.5577586 ,  76078.86129885,  40735.08051731,  63987.56787358,
#         45385.57798856,  53756.47343682,  54686.57293107,  37014.6825403 ,
#         81659.45826435,  63987.56787358,  92820.65219537,  47245.77697706,
#        124444.0349999 , 110492.54258614,  61197.26939083,  90030.35371261,
#        122583.8360114 ,  63057.46837933,  74218.66231034,  56546.77191957])

# %%
print("Training set")
plt.scatter(x_train,y_train,color="green")
plt.plot(x_train,x_pred,color="red")
plt.show()
# Out:
# Training set

# %%
print("Test Set")
plt.scatter(x_test,y_test,color="blue")
plt.plot(x_train,x_pred,color='red')
plt.show()
# Out:
# Test Set
